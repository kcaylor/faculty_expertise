# %% [markdown]
# # Core Unit Management
#
# This notebook defines the core `Unit` class and the method factory to dispatch the correct scraping function for each unit. It is part of a modular framework for scraping and enriching faculty directories using `nbdev`.
#
# ## Features
# - Defines the `Unit` object to manage scraping and enrichment
# - Uses a strategy pattern to dispatch custom scraper functions
# - Enables reusable enrichment functions (e.g., OpenAI-powered expertise summarization)

# %%
#| default_exp core

# %%
#| export
from pathlib import Path
import pandas as pd
from faculty_expertise.my_enrichment import gather_research_links, get_corpus_from_urls, summarize_faculty_expertise

# %% [markdown]
# ## Unit class

# %%
#| export
from faculty_expertise.my_scrapers import get_scraper

class Unit:
    "Encapsulates scraping and enrichment for a given academic unit"
    def __init__(self, name, html_file, base_url=None, scraper_func=None, metadata=None):
        self.name = name
        self.html_file = Path(html_file)
        self.base_url = base_url
        self.scraper_func = scraper_func or get_scraper(name)
        self.metadata = metadata or {}
        self.df = None

    def scrape(self):
        "Run the unit's scraper function and return a DataFrame"
        self.df = self.scraper_func(self.html_file, self.base_url)
        self.df["Unit"] = self.name
        return self.df

    def enrich_with(self, enrich_func, source_field="Website", target_field="Expertise"):
        "Apply an enrichment function to a field (e.g., summarizing expertise from faculty websites)"
        if self.df is None:
            raise ValueError("You must call scrape() first.")
        self.df[target_field] = self.df[source_field].apply(
            lambda url: enrich_func(url) if pd.notnull(url) else None
        )

# %% [markdown]
# ## Examples and Tests

# %%
#| eval: false

# Example test: dummy scraper
def dummy_scraper(file_path, base_url):
    return pd.DataFrame([{
        "Name": "Alice Example",
        "Website": "http://example.com"
    }])

u = Unit("TestUnit", "dummy.html", base_url="http://example.com", scraper_func=dummy_scraper)
df = u.scrape()
assert "Name" in df.columns
assert u.name == "TestUnit"

# %% [markdown]
# ## Art Department Example
#
# Test out the art department

# %%
art = Unit("Art", "../faculty_html/art.html", base_url="https://www.arts.ucsb.edu")
art.scrape()
# Out:
#                     Name                      Title(s)  \
# 0   Sarah Rosalena Brady           Assistant Professor
# 1         Jane Callister                     Professor
# 2           Iman Djouini  Assistant Teaching Professor
# 3            Kip Fulbeck                     Professor
# 4          Lisa Jevbratt                     Professor
# 5             Alex Lukas           Associate Professor
# 6  moulton@arts.ucsb.edu                          None
# 7           Marcos Novak                     Professor
#
#                                       Specialization                   Email  \
# 0               Computational Craft and Haptic Media  rosalena@arts.ucsb.edu
# 1                                  Painting, Drawing      jane@arts.ucsb.edu
# 2                    Print, Book Arts and Intermedia    imandjouini@ucsb.edu
# 3                    Narrative, Performative Studies                    None
# 4  Software, Wool, Science, Parascience, Interspe...  jevbratt@arts.ucsb.edu
# 5                           Print & Publication Arts      alexlukas@ucsb.edu
# 6                                   Department Chair   moulton@arts.ucsb.edu
# 7                                  Interactive Media     marcos@mat.ucsb.edu
#
#   Phone            Office                                            Website  \
# 0  None         Arts 0250                      http://www.sarahrosalena.com/
# 1  None         Arts 1348                     https://www.janecallister.com/
# 2  None              None                           https://imandjouini.com/
# 3  None         Arts 2222                            https://kipfulbeck.com/
# 4  None         Arts 2224                               http://jevbratt.com/
# 5  None              None      https://www.arts.ucsb.edu/faculty/alex-lukas/
# 6  None         Arts 2326  https://www.arts.ucsb.edumailto:moulton@arts.u...
# 7  None  Elings Hall 2207                      http://translab.mat.ucsb.edu/
#
#   Photo URL Unit
# 0      None  Art
# 1      None  Art
# 2      None  Art
# 3      None  Art
# 4      None  Art
# 5      None  Art
# 6      None  Art
# 7      None  Art

# %%
# Test to ensure the scraper works
df = art.df 
# How many rows?
print(f"Number of rows: {len(df)}")
# Provide exmaples of the data in a clean format with a nice looking table:
df.head(5).style.set_properties(**{'text-align': 'left'}).set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'left')]}]
)
# Out:
# Number of rows: 8
# <style type="text/css">
# #T_69996 th {
#   text-align: left;
# }
# #T_69996_row0_col0, #T_69996_row0_col1, #T_69996_row0_col2, #T_69996_row0_col3, #T_69996_row0_col4, #T_69996_row0_col5, #T_69996_row0_col6, #T_69996_row0_col7, #T_69996_row0_col8, #T_69996_row1_col0, #T_69996_row1_col1, #T_69996_row1_col2, #T_69996_row1_col3, #T_69996_row1_col4, #T_69996_row1_col5, #T_69996_row1_col6, #T_69996_row1_col7, #T_69996_row1_col8, #T_69996_row2_col0, #T_69996_row2_col1, #T_69996_row2_col2, #T_69996_row2_col3, #T_69996_row2_col4, #T_69996_row2_col5, #T_69996_row2_col6, #T_69996_row2_col7, #T_69996_row2_col8, #T_69996_row3_col0, #T_69996_row3_col1, #T_69996_row3_col2, #T_69996_row3_col3, #T_69996_row3_col4, #T_69996_row3_col5, #T_69996_row3_col6, #T_69996_row3_col7, #T_69996_row3_col8, #T_69996_row4_col0, #T_69996_row4_col1, #T_69996_row4_col2, #T_69996_row4_col3, #T_69996_row4_col4, #T_69996_row4_col5, #T_69996_row4_col6, #T_69996_row4_col7, #T_69996_row4_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_69996">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69996_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_69996_level0_col1" class="col_heading level0 col1" >Title(s)</th>
#       <th id="T_69996_level0_col2" class="col_heading level0 col2" >Specialization</th>
#       <th id="T_69996_level0_col3" class="col_heading level0 col3" >Email</th>
#       <th id="T_69996_level0_col4" class="col_heading level0 col4" >Phone</th>
#       <th id="T_69996_level0_col5" class="col_heading level0 col5" >Office</th>
#       <th id="T_69996_level0_col6" class="col_heading level0 col6" >Website</th>
#       <th id="T_69996_level0_col7" class="col_heading level0 col7" >Photo URL</th>
#       <th id="T_69996_level0_col8" class="col_heading level0 col8" >Unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69996_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69996_row0_col0" class="data row0 col0" >Sarah Rosalena Brady</td>
#       <td id="T_69996_row0_col1" class="data row0 col1" >Assistant Professor</td>
#       <td id="T_69996_row0_col2" class="data row0 col2" >Computational Craft and Haptic Media</td>
#       <td id="T_69996_row0_col3" class="data row0 col3" >rosalena@arts.ucsb.edu</td>
#       <td id="T_69996_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_69996_row0_col5" class="data row0 col5" >Arts 0250</td>
#       <td id="T_69996_row0_col6" class="data row0 col6" >http://www.sarahrosalena.com/</td>
#       <td id="T_69996_row0_col7" class="data row0 col7" >None</td>
#       <td id="T_69996_row0_col8" class="data row0 col8" >Art</td>
#     </tr>
#     <tr>
#       <th id="T_69996_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69996_row1_col0" class="data row1 col0" >Jane Callister</td>
#       <td id="T_69996_row1_col1" class="data row1 col1" >Professor</td>
#       <td id="T_69996_row1_col2" class="data row1 col2" >Painting, Drawing</td>
#       <td id="T_69996_row1_col3" class="data row1 col3" >jane@arts.ucsb.edu</td>
#       <td id="T_69996_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_69996_row1_col5" class="data row1 col5" >Arts 1348</td>
#       <td id="T_69996_row1_col6" class="data row1 col6" >https://www.janecallister.com/</td>
#       <td id="T_69996_row1_col7" class="data row1 col7" >None</td>
#       <td id="T_69996_row1_col8" class="data row1 col8" >Art</td>
#     </tr>
#     <tr>
#       <th id="T_69996_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69996_row2_col0" class="data row2 col0" >Iman Djouini</td>
#       <td id="T_69996_row2_col1" class="data row2 col1" >Assistant Teaching Professor</td>
#       <td id="T_69996_row2_col2" class="data row2 col2" >Print, Book Arts and Intermedia</td>
#       <td id="T_69996_row2_col3" class="data row2 col3" >imandjouini@ucsb.edu</td>
#       <td id="T_69996_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_69996_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_69996_row2_col6" class="data row2 col6" >https://imandjouini.com/</td>
#       <td id="T_69996_row2_col7" class="data row2 col7" >None</td>
#       <td id="T_69996_row2_col8" class="data row2 col8" >Art</td>
#     </tr>
#     <tr>
#       <th id="T_69996_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69996_row3_col0" class="data row3 col0" >Kip Fulbeck</td>
#       <td id="T_69996_row3_col1" class="data row3 col1" >Professor</td>
#       <td id="T_69996_row3_col2" class="data row3 col2" >Narrative, Performative Studies</td>
#       <td id="T_69996_row3_col3" class="data row3 col3" >None</td>
#       <td id="T_69996_row3_col4" class="data row3 col4" >None</td>
#       <td id="T_69996_row3_col5" class="data row3 col5" >Arts 2222</td>
#       <td id="T_69996_row3_col6" class="data row3 col6" >https://kipfulbeck.com/</td>
#       <td id="T_69996_row3_col7" class="data row3 col7" >None</td>
#       <td id="T_69996_row3_col8" class="data row3 col8" >Art</td>
#     </tr>
#     <tr>
#       <th id="T_69996_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_69996_row4_col0" class="data row4 col0" >Lisa Jevbratt</td>
#       <td id="T_69996_row4_col1" class="data row4 col1" >Professor</td>
#       <td id="T_69996_row4_col2" class="data row4 col2" >Software, Wool, Science, Parascience, Interspecies, Participatory, Epistemology, Data, Weaving, Network, Ontology</td>
#       <td id="T_69996_row4_col3" class="data row4 col3" >jevbratt@arts.ucsb.edu</td>
#       <td id="T_69996_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_69996_row4_col5" class="data row4 col5" >Arts 2224</td>
#       <td id="T_69996_row4_col6" class="data row4 col6" >http://jevbratt.com/</td>
#       <td id="T_69996_row4_col7" class="data row4 col7" >None</td>
#       <td id="T_69996_row4_col8" class="data row4 col8" >Art</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test the get_expertise_from_url function for a single URL in the art.df dataframe
row = art.df.iloc[0]
result = enrich_faculty_row(row)

# %%
# Print the result in a nice format:
print(f"Website: {row['Website']}")
print(f"Name: {row['Name']}")
print("Enriched Data:")
for key, value in result.items():
    print(f"  {key}: {value}")
# Out:
# Website: http://www.sarahrosalena.com/
# Name: Sarah Rosalena Brady
# Enriched Data:
#   Crawled URLs: ['http://www.sarahrosalena.com/bio', 'http://www.sarahrosalena.com/', 'http://www.sarahrosalena.com/cv']
#   ORCID URL: None
#   Google Scholar URL: None
#   CV URL: None
#   Research Title: Interdisciplinary Approaches to Computational Craft and Haptic Media
#   Expertise: Sarah Rosalena explores the intersection of traditional handicraft traditions with emerging technology, focusing on the hybrid forms that challenge the boundaries between ancient and future, tradition and innovation.
#   Research Description: Sarah Rosalena's research navigates the rich terrain between traditional handicraft and cutting-edge technology. By integrating Indigenous cosmologies with digital tools, she creates artworks that defy conventional categorizations, blurring the lines between high and low tech, human and nonhuman. Her work with digital Jacquard looms, 3D ceramic printers, and image software reinterprets traditional craft techniques through a modern lens, producing textiles and 'anti-vessels' that reflect a synthesis of natural and synthetic aesthetics. Rosalena's recent projects delve into the geopolitical impacts of climate change, artificial intelligence, and extractive industries, imagining futures liberated from these constraints. Her innovative approach not only redefines craft in the context of art history and technology but also offers a critical perspective on the societal and environmental implications of our increasingly digital world.
#   Topics: ['Computational Craft', 'Haptic Media', 'Indigenous Cosmologies', 'Digital Art', 'Environmental Impact of Technology']
#   Methods: ['Digital Jacquard Loom Weaving', '3D Ceramic Printing', 'Image Software Manipulation']
#   Geographic Focus: ['Global']
#   Keywords: ['Computational Craft', 'Haptic Media', 'Indigenous Art', 'Digital Technology', 'Experimental Practice', 'Climate Change', 'Artificial Intelligence', 'Extractive Industries']
#   Disciplines: ['Art', 'Technology', 'Environmental Studies']
#   Potential Applications: ['Artistic Expression', 'Cultural Preservation', 'Environmental Awareness', 'Technological Innovation']
